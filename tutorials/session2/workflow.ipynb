# %% [markdown]
# # Building a Workflow for the NYU Retinotopy Dataset

# %% [markdown]
# ## About this Notebook

# %% [markdown]
# This notebook is an example of how you can construct an entire preprocessing pipeline for an fMRI dataset of a visual experiment. We use the NYU Retinotopy Dataset ([paper](https://doi.org/10.1016/j.neuroimage.2021.118609), [dataset](https://openneuro.org/datasets/ds003787/)), in which participants participated in retinotopic mapping scans, as an example dataset.
#
# This notebook was made for the 2024 VSS Workshop [*How to stop worrying and love neuroimaging of the visual cortex*](https://noahbenson.github.io/vss2024), and it is specifically designed to run seamlessly inside of a [Neurodesk](https://neurodesk.org/) instance. Neurodesk instances can be run in the cloud, on high performance compute clusters (using singularity), or by using [Docker](https://docker.com/). For information on running Neurodesk locally for use with this notebook, see the README file of the [GitHub repository](https://github.com/noahbenson/vss2024) associated with the workshop.
#
# Part of what makes this notebook useful is that it serves as an example of a complete reproducible preprocessing pipeline. All of the steps in this notebook use open source software whose versions are noted in the notebook itself. Because the notebook is designed to run in Neurodesk, many of the issues related to software versions and installation are eliminated. The [GitHub repository for the workshop](https://github.com/noahbenson/vss2024) additionally demonstrates how to use Docker and `docker-compose` to allow others to access the same environment in which you run these preprocessing steps.
#
# This tutorial is by [Noah C. Benson](https://nben.net/) (eScience Institute, University of Washington). Please email [nben@uw.edu](mailto:nben@uw.edu) if you have any questions.

# %% [markdown]
# ### Notebook Organization and Goals

# %% [markdown]
# The notebook is organized into steps, which, when run in order in a clean Neurodesk instance, should consist of an entire preprocessing workflow for a single subject. Note that some of the steps, such as running `fMRIprep`, produce a lot of output. **If you are running this notebook outside of the Neurodesk virtual compute instance set up for the VSS 2024 workshop, then you will need to follow the instructions below on obtaining the dataset**. Alternatively, if you have your own dataset that you wish to analyze, you can upload it and preprocess it instead (doing so will require changing some of the settings and commands below).
#
# The goal of the workflow in this notebook is to preprocess the data of a single subject of the NYU Retinotopy Dataset (though only minor changes are needed to the notebook to enable it to preprocess the entire dataset). We begin the workflow with the assumption that the dataset is already in BIDS format, but we then complete all of the following steps:
#
# 1. **Preprocess the dataset using fMRIprep**. This step performs most major preprocessing steps, including fieldmap unwarping, slice time correction, skull stripping, gray-/white-matter segmentation, image normalization, and all cortical surface modeling steps performed by FreeSurfer.
# 2. **Solve population receptive field (PRF) models models**. This step converts the BOLD timeseries (measured during the retinotopic mapping scans) from each point on the cortical surface into estimates of the PRF center (*x*, *y* in degrees of the visual field), PRF size (*\u03C3*, in degrees of the visual field), and the fraction of variance from the timeseries that is explained by the PRF model.
# 3. **Visualize the retinotopic maps and label visual areas**. This step annotates which regions of cortex are part of V1, V2, V3, hV4, and a number of other visual areas.

# %% [markdown]
# ### About the Dataset

# %% [markdown]
# The NYU Retinotopy Dataset ([paper](https://doi.org/10.1016/j.neuroimage.2021.118609), [dataset](https://openneuro.org/datasets/ds003787/)) was originally collected with the intention of verifying the reproducibility of various observations about human vision that came out of the much larger Human Connectome Project 7 Tesla Retinotopy Dataset ([paper](https://doi.org/10.1167/18.13.23), [dataset](https://osf.io/bw9ec/)). Subjects participated in at least two T1-weighted scans and at least six retinotopic mapping scans (192 seconds each) consisting of drifting bars containing colorful images (similar to the stimulus used in the HCP protocol, but with only bars instead of bars, rings, and wedges).
#
# #### Obtaining the Dataset
# **You can skip these steps if you are running this notebook in the virtual Neurodesk instance set up for the VSS Workshop.** During the workshop, the NYU Retinotopy Dataset will be downloaded ahead of time and will be available in the directory `/home/jovyan/shared/lec-02/data/NYU_full`. If you are running this notebook in another environment (such as on your own computer), you will need to make sure that the dataset is downloaded ahead of time. To ensure the dataset is downloaded, you will need to run the following commands (you will need to copy-paste these into new cells and run them).
#
# First, run the following shell-commands to install tools for downloading data from OpenNeuro. You will need to copy-and-paste these code blocks into Jupyter cells to run them:
# ```bash
# %%bash
#
# # First, we need to install cloudpathlib, which lets us download data
# # from AWS S3 service, where OpenNeuro datasets are stored.
# pip install 'cloudpathlib[s3] == 0.18.1'
#
# # Next, we need to make a directory for our dataset. We use the same
# # directory that was used in the VSS workshop so that we don't need to
# # change the paths in this notebook.
# mkdir -p /home/jovyan/shared/lec-02/data/step0_raw
# # We also need a directory for the stimulus files.
# mkdir -p /home/jovyan/shared/lec-02/data/stimulus
# ```
#
# Then, run this Python code in a separate cell to download the dataset. Note that this will take quite some time to run (this is normal):
#
# ```python
# from cloudpathlib import S3Path, S3Client
# from pathlib import Path
#
# data_path = S3Path(
#     's3://openneuro.org/ds003787/',
#     client=S3Client(no_sign_request=True))
# dest_path = Path(
#     '/home/jovyan/shared/lec-02/data/step0_raw')
# print("Downloading files:")
# print("Downloading files for sub-wlsubj001...")
# subpath = data_path / 'sub-wlsubj001'
# subpath.download_to(dest_path / 'sub-wlsubj001')
# # Also download the stimulus (all subjects / sessions are the same):
# stim_path = data_path / 'derivatives' / 'stimulus_apertures'
# stim_path = stim_path / 'sub-wlsubj001' / 'ses-nyu3t01'
# stim_path = stim_path / 'sub-wlsubj001_ses-nyu3t01_task-prf_apertures.nii.gz'
# stim_path.download_to(
#     '/home/jovyan/shared/lec-02/data/stimulus/task-prf_apertures.nii.gz')
# ```
#
# Finally, you will need to upload a license file for FreeSurfer to your home directory and name it `fslicense`. This is only needed if you intend to run fMRIprep. You can upload the file by dragging it into the file browser menu of JupyterLab while you are viewing your home directory. More information on obtaining a license file is below in the first code cell.

# %% [markdown]
# ## Configuration

# %% [markdown]
# We begin the workflow by configuring a few meta-data items. These pieces of data largely tell the workflow where to find various data. We set these variables in the `os.environ` dictionary, which represents the Operating System's environment for the currently running notebook. The OS environment is a dictionary of strings that is inherited by any process or command that is started by the notebook, so if we run a bash script or a FreeSurfer command from this notebook, then that script or command will also inherit these values. See the [Wikipedia page on Environment Variables](https://en.wikipedia.org/wiki/Environment_variable) for more information.

# %%
from os import environ

# The path where we can find the raw MRI scans in BIDS format.
environ['RAWDATA_DIR'] = '/home/jovyan/shared/lec-02/data/step0_raw'

# The work directory in which we make and run the workflow.
environ['WORK_DIR'] = '/home/jovyan/work'

# The output path, in which the preprocessed data will be stored in BIDS format.
environ['PREPROC_DIR'] = f'{environ["WORK_DIR"]}/BIDS'

# The file that contains the stimulus apertures used in the experiment.
environ['STIMULUS_FILE'] = '/home/jovyan/shared/lec-02/data/stimulus/task-prf_apertures.nii.gz'

# To run fMRIprep using FreeSurfer, you need a license from FreeSurfer. These
# are free. See https://surfer.nmr.mgh.harvard.edu/fswiki/License for information.
# This should be the path to that license file.
environ['FS_LICENSE'] = '/home/jovyan/fslicense'

# The number of threads to run.
environ['ITK_GLOBAL_DEFAULT_NUMBER_OF_THREADS'] = '4'

# This fixes a warning from matplotlib when fMRIprep starts up in Neurodesk.
environ['MPLCONFIGDIR'] = '/home/jovyan/.matplotlib-mpldir'

# %% [markdown]
# Next, make sure that we're in the work directory.

# %%
from os import chdir

chdir(environ['WORK_DIR'])

# %% [markdown]
# We want to make sure that these directories exist before we run the rest of this notebook.

# %%
# %%bash
#
# mkdir -p BIDS
# mkdir -p tmp
# mkdir -p config

# %% [markdown]
# ## Step 1. Run fMRIprep

# %% [markdown]
# The first step in preprocessing the data for this project is to use `fMRIprep` to perform most of the basic preprocessing.
# We will preprocess this dataset using the `fMRIprep` version noted in the **Configuration** section above.

# %% [markdown]
# ### Load the fMRIprep module

# %%
# Load the fMRIprep module.
import lmod
await lmod.load(f'fmriprep/23.2.1')

# %% [markdown]
# ### Run the fMRIprep command

# %%
# %%bash
#
# # Run the fMRIprep command:
# fmriprep "$RAWDATA_DIR" "$PREPROC_DIR" participant \
#     --participant-label wlsubj001 \
#     --output-spaces T1w fsnative \
#     --bold2t1w-init header \
#     --fs-license-file "$FS_LICENSE" \
#     --nprocs "$ITK_GLOBAL_DEFAULT_NUMBER_OF_THREADS" \
#     --mem 12000 \
#     -w tmp/fmriprep \
#     --skip_bids_validation \
#     --verbose
# Out:
# You are using fMRIPrep-23.2.1, and a newer version of fMRIPrep is available: 23.2.2.
# Please check out our documentation about how and when to upgrade:
# https://fmriprep.readthedocs.io/en/latest/faq.html#upgrading
# 240513-19:53:30,805 cli INFO:
# 	 Telemetry system to collect crashes and errors is enabled - thanks for your feedback!. Use option ``--notrack`` to opt out.
# 240513-19:55:40,302 nipype.workflow IMPORTANT:
# 	 Running fMRIPrep version 23.2.1
#
#          License NOTICE ##################################################
#          fMRIPrep 23.2.1
#          Copyright 2023 The NiPreps Developers.
#
#          This product includes software developed by
#          the NiPreps Community (https://nipreps.org/).
#
#          Portions of this software were developed at the Department of
#          Psychology at Stanford University, Stanford, CA, US.
#
#          This software is also distributed as a Docker container image.
#          The bootstrapping file for the image ("Dockerfile") is licensed
#          under the MIT License.
#
#          This software may be distributed through an add-on package called
#          "Docker Wrapper" that is under the BSD 3-clause License.
#          #################################################################
# 240513-19:56:31,621 nipype.workflow IMPORTANT:
# 	 Building fMRIPrep's workflow:
#            * BIDS dataset path: /home/jovyan/shared/lec-02/data/step0_raw.
#            * Participant list: ['wlsubj001'].
#            * Run identifier: 20240513-195329_40a4ea69-25ed-48a1-8bd5-ece890ab0886.
#            * Output spaces: T1w fsnative.
#            * Pre-run FreeSurfer's SUBJECTS_DIR: /home/jovyan/work/BIDS/sourcedata/freesurfer.
# 240513-19:56:38,884 nipype.workflow INFO:
# 	 ANAT Stage 1: Adding template workflow
# 240513-19:56:39,683 nipype.workflow INFO:
# 	 ANAT Stage 2: Preparing brain extraction workflow
# 240513-19:56:39,787 nipype.workflow INFO:
# 	 ANAT Stage 3: Preparing segmentation workflow
# 240513-19:56:39,792 nipype.workflow INFO:
# 	 ANAT Stage 4: Preparing normalization workflow for ['MNI152NLin2009cAsym']
# 240513-19:56:39,804 nipype.workflow INFO:
# 	 ANAT Stage 5: Preparing surface reconstruction workflow
# 240513-19:56:39,826 nipype.workflow INFO:
# 	 ANAT Stage 6: Preparing mask refinement workflow
# 240513-19:56:39,829 nipype.workflow INFO:
# 	 ANAT No T2w images provided - skipping Stage 7
# 240513-19:56:39,829 nipype.workflow INFO:
# 	 ANAT Stage 8: Creating GIFTI surfaces for ['white', 'pial', 'midthickness', 'sphere_reg', 'sphere']
# 240513-19:56:39,844 nipype.workflow INFO:
# 	 ANAT Stage 8: Creating GIFTI metrics for ['thickness', 'sulc']
# 240513-19:56:39,850 nipype.workflow INFO:
# 	 ANAT Stage 8a: Creating cortical ribbon mask
# 240513-19:56:39,853 nipype.workflow INFO:
# 	 ANAT Stage 9: Creating fsLR registration sphere
# 240513-19:56:39,862 nipype.workflow INFO:
# 	 ANAT Stage 10: Creating MSM-Sulc registration sphere
# 240513-19:58:19,414 nipype.workflow INFO:
# 	 B0 field inhomogeneity map will be estimated with the following 1 estimator(s): [<EstimatorType.PEPOLAR: 2>].
# 240513-19:58:19,472 nipype.workflow INFO:
# 	 Setting-up fieldmap "auto_00000" (EstimatorType.PEPOLAR) with <sub-wlsubj001_ses-nyu3t01_acq-fMRI_dir-AP_run-01_epi.nii.gz, sub-wlsubj001_ses-nyu3t01_acq-fMRI_dir-PA_run-01_epi.nii.gz>
# 240513-19:58:20,989 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-01_sbref.nii.gz.
# 240513-19:58:21,102 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:21,109 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:21,119 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:21,190 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:21,220 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.445s.
# 240513-19:58:22,890 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-02_sbref.nii.gz.
# 240513-19:58:22,988 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:22,993 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:22,997 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:23,60 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:23,90 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.445s.
# 240513-19:58:24,798 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-03_sbref.nii.gz.
# 240513-19:58:24,892 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:24,897 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:24,901 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:24,965 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:25,0 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.445s.
# 240513-19:58:26,590 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-04_sbref.nii.gz.
# 240513-19:58:26,684 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:26,689 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:26,693 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:26,758 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:26,792 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.446s.
# 240513-19:58:28,609 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-05_sbref.nii.gz.
# 240513-19:58:28,706 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:28,711 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:28,716 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:28,785 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:28,818 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.445s.
# 240513-19:58:30,580 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-06_sbref.nii.gz.
# 240513-19:58:30,672 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:30,677 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:30,681 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:30,745 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:30,778 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.446s.
# 240513-19:58:32,778 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-07_sbref.nii.gz.
# 240513-19:58:32,875 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:32,880 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:32,884 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:32,948 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:32,981 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.445s.
# 240513-19:58:35,9 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-08_sbref.nii.gz.
# 240513-19:58:35,106 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:35,110 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:35,115 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:35,177 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:35,206 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.446s.
# 240513-19:58:47,497 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-09_sbref.nii.gz.
# 240513-19:58:47,592 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:47,598 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:47,603 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:47,672 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:47,700 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.445s.
# 240513-19:58:49,530 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-10_sbref.nii.gz.
# 240513-19:58:49,624 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:49,629 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:49,634 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:49,698 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:49,738 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.445s.
# 240513-19:58:51,622 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-11_sbref.nii.gz.
# 240513-19:58:51,717 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:51,721 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:51,726 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:51,787 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:51,821 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.446s.
# 240513-19:58:53,409 nipype.workflow INFO:
# 	 Using single-band reference file(s) sub-wlsubj001_ses-nyu3t01_task-prf_acq-PA_run-12_sbref.nii.gz.
# 240513-19:58:53,502 nipype.workflow INFO:
# 	 Stage 1: Adding HMC boldref workflow
# 240513-19:58:53,507 nipype.workflow INFO:
# 	 Stage 2: Adding motion correction workflow
# 240513-19:58:53,511 nipype.workflow INFO:
# 	 Stage 3: Adding coregistration boldref workflow
# 240513-19:58:53,573 nipype.workflow WARNING:
# 	 Initializing BBR with header; affine fallback disabled
# 240513-19:58:53,600 nipype.workflow IMPORTANT:
# 	 BOLD series will be slice-timing corrected to an offset of 0.445s.
# 240513-19:58:59,680 nipype.workflow INFO:
# 	 fMRIPrep workflow graph with 2471 nodes built successfully.
# 240513-20:00:49,844 nipype.workflow IMPORTANT:
# 	 fMRIPrep started!
# 240513-20:00:51,861 nipype.workflow INFO:
# 	 Workflow fmriprep_23_2_wf settings: ['check', 'execution', 'logging', 'monitoring']
# 240513-20:00:52,874 nipype.workflow INFO:
# 	 Running in parallel.
# 240513-20:00:52,879 nipype.workflow WARNING:
# 	 Some nodes exceed the total amount of memory available (12.00GB).
# 240513-20:00:52,879 nipype.workflow WARNING:
# 	 Some nodes demand for more threads than available (4).
# 240513-20:00:52,910 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 106 jobs ready. Free memory (GB): 12.00/12.00, Free processors: 4/4.
# 240513-20:00:53,449 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.fsdir_run_20240513_195329_40a4ea69_25ed_48a1_8bd5_ece890ab0886" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/fsdir_run_20240513_195329_40a4ea69_25ed_48a1_8bd5_ece890ab0886".
# 240513-20:00:53,511 nipype.workflow INFO:
# 	 [Node] Executing "fsdir_run_20240513_195329_40a4ea69_25ed_48a1_8bd5_ece890ab0886" <niworkflows.interfaces.bids.BIDSFreeSurferDir>
# 240513-20:01:09,301 nipype.workflow INFO:
# 	 [Node] Finished "fsdir_run_20240513_195329_40a4ea69_25ed_48a1_8bd5_ece890ab0886", elapsed time 15.783424s.
# 240513-20:01:09,354 nipype.workflow INFO:
# 	 [Job 0] Completed (fmriprep_23_2_wf.fsdir_run_20240513_195329_40a4ea69_25ed_48a1_8bd5_ece890ab0886).
# 240513-20:01:09,595 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.about" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/about".
# 240513-20:01:09,659 nipype.workflow INFO:
# 	 [Node] Executing "about" <fmriprep.interfaces.reports.AboutSummary>
# 240513-20:01:09,668 nipype.workflow INFO:
# 	 [Node] Finished "about", elapsed time 0.008482s.
# 240513-20:01:09,710 nipype.workflow INFO:
# 	 [Job 2] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.about).
# 240513-20:01:10,13 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 101 jobs ready. Free memory (GB): 11.20/12.00, Free processors: 0/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.full_wm
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.res_tmpl
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bidssrc
# 240513-20:01:12,206 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.full_wm" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/anat_fit_wf/brain_extraction_wf/full_wm".
# 240513-20:01:12,276 nipype.workflow INFO:
# 	 [Node] Executing "full_wm" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:12,302 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.res_tmpl" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/anat_fit_wf/brain_extraction_wf/res_tmpl".
# 240513-20:01:12,307 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/anat_fit_wf/brain_extraction_wf/lap_tmpl".
# 240513-20:01:12,360 nipype.workflow INFO:
# 	 [Node] Executing "res_tmpl" <niworkflows.interfaces.nibabel.RegridToZooms>
# 240513-20:01:12,378 nipype.workflow INFO:
# 	 [Node] Executing "lap_tmpl" <nipype.interfaces.ants.utils.ImageMath>
# 240513-20:01:12,757 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bidssrc" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bidssrc".
# 240513-20:01:12,826 nipype.workflow INFO:
# 	 [Node] Finished "full_wm", elapsed time 0.546047s.
# 240513-20:01:12,838 nipype.workflow INFO:
# 	 [Node] Executing "bidssrc" <niworkflows.interfaces.bids.BIDSDataGrabber>
# 240513-20:01:12,841 nipype.interface INFO:
# 	 No "t2w" images found for sub-wlsubj001
# 240513-20:01:12,842 nipype.interface INFO:
# 	 No "flair" images found for sub-wlsubj001
# 240513-20:01:12,842 nipype.interface INFO:
# 	 No "roi" images found for sub-wlsubj001
# 240513-20:01:12,842 nipype.interface INFO:
# 	 No "pet" images found for sub-wlsubj001
# 240513-20:01:12,842 nipype.interface INFO:
# 	 No "asl" images found for sub-wlsubj001
# 240513-20:01:12,842 nipype.workflow INFO:
# 	 [Node] Finished "bidssrc", elapsed time 0.000732s.
# 240513-20:01:13,600 nipype.workflow INFO:
# 	 [Node] Finished "res_tmpl", elapsed time 1.235897s.
# 240513-20:01:14,14 nipype.workflow INFO:
# 	 [Job 1] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bidssrc).
# 240513-20:01:14,16 nipype.workflow INFO:
# 	 [Job 3] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.res_tmpl).
# 240513-20:01:14,18 nipype.workflow INFO:
# 	 [Job 4] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.full_wm).
# 240513-20:01:14,22 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 104 jobs ready. Free memory (GB): 11.80/12.00, Free processors: 3/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl
# 240513-20:01:14,255 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf/bold_fit_wf/ds_hmc_boldref_wf/raw_sources".
# 240513-20:01:14,256 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.hmc_boldref_wf.get_dummy" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf/bold_fit_wf/hmc_boldref_wf/get_dummy".
# 240513-20:01:14,321 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.hmc_boldref_wf.val_bold" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf/bold_fit_wf/hmc_boldref_wf/val_bold".
# 240513-20:01:14,328 nipype.workflow INFO:
# 	 [Node] Executing "get_dummy" <niworkflows.interfaces.bold.NonsteadyStatesDetector>
# 240513-20:01:14,329 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:14,330 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.00058s.
# 240513-20:01:14,379 nipype.workflow INFO:
# 	 [Node] Executing "val_bold" <niworkflows.interfaces.header.ValidateImage>
# 240513-20:01:16,18 nipype.workflow INFO:
# 	 [Job 8] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources).
# 240513-20:01:16,23 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 101 jobs ready. Free memory (GB): 11.59/12.00, Free processors: 1/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.hmc_boldref_wf.get_dummy
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.hmc_boldref_wf.val_bold
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl
# 240513-20:01:16,278 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.ds_hmc_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf/bold_fit_wf/ds_hmc_wf/raw_sources".
# 240513-20:01:16,335 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:16,336 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000518s.
# 240513-20:01:16,622 nipype.workflow INFO:
# 	 [Node] Finished "get_dummy", elapsed time 2.292753s.
# 240513-20:01:18,18 nipype.workflow INFO:
# 	 [Job 7] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.hmc_boldref_wf.get_dummy).
# 240513-20:01:18,20 nipype.workflow INFO:
# 	 [Job 9] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.ds_hmc_wf.raw_sources).
# 240513-20:01:18,24 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 101 jobs ready. Free memory (GB): 11.79/12.00, Free processors: 2/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.hmc_boldref_wf.val_bold
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl
# 240513-20:01:18,271 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.ds_fmapreg_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf/bold_fit_wf/ds_fmapreg_wf/raw_sources".
# 240513-20:01:18,273 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_native_wf.bold_source" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf/bold_native_wf/bold_source".
# 240513-20:01:18,332 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:18,333 nipype.workflow INFO:
# 	 [Node] Executing "bold_source" <nipype.interfaces.utility.base.Select>
# 240513-20:01:18,333 nipype.workflow INFO:
# 	 [Node] Finished "bold_source", elapsed time 0.000202s.
# 240513-20:01:18,334 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000382s.
# 240513-20:01:20,20 nipype.workflow INFO:
# 	 [Job 10] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.ds_fmapreg_wf.raw_sources).
# 240513-20:01:20,22 nipype.workflow INFO:
# 	 [Job 11] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_native_wf.bold_source).
# 240513-20:01:20,25 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 100 jobs ready. Free memory (GB): 11.79/12.00, Free processors: 2/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.hmc_boldref_wf.val_bold
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl
# 240513-20:01:20,266 nipype.workflow INFO:
# 	 [Node] Finished "lap_tmpl", elapsed time 7.706881s.
# 240513-20:01:20,290 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_native_wf.distortion_params" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf/bold_native_wf/distortion_params".
# 240513-20:01:20,894 nipype.workflow INFO:
# 	 [Node] Executing "distortion_params" <fmriprep.interfaces.resampling.DistortionParameters>
# 240513-20:01:20,896 nipype.workflow INFO:
# 	 [Node] Finished "distortion_params", elapsed time 0.0019s.
# 240513-20:01:20,957 nipype.workflow INFO:
# 	 [Job 12] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_native_wf.distortion_params).
# 240513-20:01:21,227 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.ds_bold_t1_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf/ds_bold_t1_wf/raw_sources".
# 240513-20:01:21,228 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.fmap_preproc_wf.out_merge_fmap_id" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/fmap_preproc_wf/out_merge_fmap_id".
# 240513-20:01:21,288 nipype.workflow INFO:
# 	 [Node] Executing "out_merge_fmap_id" <nipype.interfaces.utility.base.Merge>
# 240513-20:01:21,289 nipype.workflow INFO:
# 	 [Node] Finished "out_merge_fmap_id", elapsed time 0.000214s.
# 240513-20:01:21,289 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:21,290 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000423s.
# 240513-20:01:22,20 nipype.workflow INFO:
# 	 [Job 5] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.anat_fit_wf.brain_extraction_wf.lap_tmpl).
# 240513-20:01:22,22 nipype.workflow INFO:
# 	 [Job 13] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.ds_bold_t1_wf.raw_sources).
# 240513-20:01:22,23 nipype.workflow INFO:
# 	 [Job 14] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.fmap_preproc_wf.out_merge_fmap_id).
# 240513-20:01:22,27 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 98 jobs ready. Free memory (GB): 11.99/12.00, Free processors: 3/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:22,285 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.fmap_preproc_wf.out_merge_method" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/fmap_preproc_wf/out_merge_method".
# 240513-20:01:22,288 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.hmc_boldref_wf.get_dummy" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf/bold_fit_wf/hmc_boldref_wf/get_dummy".
# 240513-20:01:22,293 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.hmc_boldref_wf.val_bold" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf/bold_fit_wf/hmc_boldref_wf/val_bold".
# 240513-20:01:22,343 nipype.workflow INFO:
# 	 [Node] Executing "out_merge_method" <nipype.interfaces.utility.base.Merge>
# 240513-20:01:22,344 nipype.workflow INFO:
# 	 [Node] Finished "out_merge_method", elapsed time 0.000172s.
# 240513-20:01:22,355 nipype.workflow INFO:
# 	 [Node] Executing "get_dummy" <niworkflows.interfaces.bold.NonsteadyStatesDetector>
# 240513-20:01:22,361 nipype.workflow INFO:
# 	 [Node] Executing "val_bold" <niworkflows.interfaces.header.ValidateImage>
# 240513-20:01:24,24 nipype.workflow INFO:
# 	 [Job 15] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.fmap_preproc_wf.out_merge_method).
# 240513-20:01:24,29 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 95 jobs ready. Free memory (GB): 11.78/12.00, Free processors: 1/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.hmc_boldref_wf.get_dummy
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.hmc_boldref_wf.val_bold
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:24,609 nipype.workflow INFO:
# 	 [Node] Finished "get_dummy", elapsed time 2.252679s.
# 240513-20:01:24,671 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf/bold_fit_wf/ds_hmc_boldref_wf/raw_sources".
# 240513-20:01:24,734 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:24,735 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000398s.
# 240513-20:01:24,816 nipype.workflow INFO:
# 	 [Node] Finished "val_bold", elapsed time 10.436279s.
# 240513-20:01:26,24 nipype.workflow INFO:
# 	 [Job 6] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_fit_wf.hmc_boldref_wf.val_bold).
# 240513-20:01:26,25 nipype.workflow INFO:
# 	 [Job 18] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.hmc_boldref_wf.get_dummy).
# 240513-20:01:26,26 nipype.workflow INFO:
# 	 [Job 19] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources).
# 240513-20:01:26,29 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 97 jobs ready. Free memory (GB): 11.99/12.00, Free processors: 3/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:26,278 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.ds_hmc_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf/bold_fit_wf/ds_hmc_wf/raw_sources".
# 240513-20:01:26,280 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.ds_fmapreg_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf/bold_fit_wf/ds_fmapreg_wf/raw_sources".
# 240513-20:01:26,281 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_native_wf.bold_source" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf/bold_native_wf/bold_source".
# 240513-20:01:26,336 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:26,338 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000531s.
# 240513-20:01:26,340 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:26,340 nipype.workflow INFO:
# 	 [Node] Executing "bold_source" <nipype.interfaces.utility.base.Select>
# 240513-20:01:26,341 nipype.workflow INFO:
# 	 [Node] Finished "bold_source", elapsed time 0.000283s.
# 240513-20:01:26,342 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000468s.
# 240513-20:01:28,24 nipype.workflow INFO:
# 	 [Job 20] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.ds_hmc_wf.raw_sources).
# 240513-20:01:28,26 nipype.workflow INFO:
# 	 [Job 21] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.ds_fmapreg_wf.raw_sources).
# 240513-20:01:28,27 nipype.workflow INFO:
# 	 [Job 22] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_native_wf.bold_source).
# 240513-20:01:28,31 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 95 jobs ready. Free memory (GB): 11.99/12.00, Free processors: 3/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:28,285 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_native_wf.distortion_params" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf/bold_native_wf/distortion_params".
# 240513-20:01:28,888 nipype.workflow INFO:
# 	 [Node] Executing "distortion_params" <fmriprep.interfaces.resampling.DistortionParameters>
# 240513-20:01:28,890 nipype.workflow INFO:
# 	 [Node] Finished "distortion_params", elapsed time 0.001309s.
# 240513-20:01:28,946 nipype.workflow INFO:
# 	 [Job 23] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_native_wf.distortion_params).
# 240513-20:01:29,204 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.ds_bold_t1_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf/ds_bold_t1_wf/raw_sources".
# 240513-20:01:29,208 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.get_dummy" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf/bold_fit_wf/hmc_boldref_wf/get_dummy".
# 240513-20:01:29,212 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.val_bold" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf/bold_fit_wf/hmc_boldref_wf/val_bold".
# 240513-20:01:29,268 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:29,269 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000405s.
# 240513-20:01:29,276 nipype.workflow INFO:
# 	 [Node] Executing "get_dummy" <niworkflows.interfaces.bold.NonsteadyStatesDetector>
# 240513-20:01:29,283 nipype.workflow INFO:
# 	 [Node] Executing "val_bold" <niworkflows.interfaces.header.ValidateImage>
# 240513-20:01:30,27 nipype.workflow INFO:
# 	 [Job 24] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.ds_bold_t1_wf.raw_sources).
# 240513-20:01:30,31 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 91 jobs ready. Free memory (GB): 11.78/12.00, Free processors: 1/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.get_dummy
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.val_bold
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:30,306 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf/bold_fit_wf/ds_hmc_boldref_wf/raw_sources".
# 240513-20:01:30,371 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:30,372 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000519s.
# 240513-20:01:32,29 nipype.workflow INFO:
# 	 [Job 27] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources).
# 240513-20:01:32,34 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 90 jobs ready. Free memory (GB): 11.78/12.00, Free processors: 1/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.get_dummy
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.val_bold
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:32,488 nipype.workflow INFO:
# 	 [Node] Finished "get_dummy", elapsed time 2.579849s.
# 240513-20:01:32,918 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.ds_hmc_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf/bold_fit_wf/ds_hmc_wf/raw_sources".
# 240513-20:01:32,977 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:32,978 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000404s.
# 240513-20:01:32,986 nipype.workflow INFO:
# 	 [Node] Finished "val_bold", elapsed time 10.624497999999999s.
# 240513-20:01:34,28 nipype.workflow INFO:
# 	 [Job 17] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_fit_wf.hmc_boldref_wf.val_bold).
# 240513-20:01:34,30 nipype.workflow INFO:
# 	 [Job 26] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.get_dummy).
# 240513-20:01:34,31 nipype.workflow INFO:
# 	 [Job 28] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.ds_hmc_wf.raw_sources).
# 240513-20:01:34,33 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 92 jobs ready. Free memory (GB): 11.99/12.00, Free processors: 3/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:34,279 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.ds_fmapreg_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf/bold_fit_wf/ds_fmapreg_wf/raw_sources".
# 240513-20:01:34,280 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_native_wf.distortion_params" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf/bold_native_wf/distortion_params".
# 240513-20:01:34,281 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_native_wf.bold_source" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf/bold_native_wf/bold_source".
# 240513-20:01:34,345 nipype.workflow INFO:
# 	 [Node] Executing "bold_source" <nipype.interfaces.utility.base.Select>
# 240513-20:01:34,345 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:34,346 nipype.workflow INFO:
# 	 [Node] Finished "bold_source", elapsed time 0.000229s.
# 240513-20:01:34,346 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000579s.
# 240513-20:01:34,757 nipype.workflow INFO:
# 	 [Node] Executing "distortion_params" <fmriprep.interfaces.resampling.DistortionParameters>
# 240513-20:01:34,758 nipype.workflow INFO:
# 	 [Node] Finished "distortion_params", elapsed time 0.000933s.
# 240513-20:01:34,812 nipype.workflow INFO:
# 	 [Job 31] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_native_wf.distortion_params).
# 240513-20:01:35,67 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.ds_bold_t1_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf/ds_bold_t1_wf/raw_sources".
# 240513-20:01:35,133 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:35,134 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000426s.
# 240513-20:01:36,31 nipype.workflow INFO:
# 	 [Job 29] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.ds_fmapreg_wf.raw_sources).
# 240513-20:01:36,33 nipype.workflow INFO:
# 	 [Job 30] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_native_wf.bold_source).
# 240513-20:01:36,34 nipype.workflow INFO:
# 	 [Job 32] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.ds_bold_t1_wf.raw_sources).
# 240513-20:01:36,37 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 89 jobs ready. Free memory (GB): 11.99/12.00, Free processors: 3/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:36,287 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.hmc_boldref_wf.get_dummy" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf/bold_fit_wf/hmc_boldref_wf/get_dummy".
# 240513-20:01:36,287 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf/bold_fit_wf/ds_hmc_boldref_wf/raw_sources".
# 240513-20:01:36,351 nipype.workflow INFO:
# 	 [Node] Executing "get_dummy" <niworkflows.interfaces.bold.NonsteadyStatesDetector>
# 240513-20:01:36,352 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:36,353 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000417s.
# 240513-20:01:36,361 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.hmc_boldref_wf.val_bold" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf/bold_fit_wf/hmc_boldref_wf/val_bold".
# 240513-20:01:36,411 nipype.workflow INFO:
# 	 [Node] Executing "val_bold" <niworkflows.interfaces.header.ValidateImage>
# 240513-20:01:38,33 nipype.workflow INFO:
# 	 [Job 35] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources).
# 240513-20:01:38,39 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 86 jobs ready. Free memory (GB): 11.78/12.00, Free processors: 1/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.hmc_boldref_wf.get_dummy
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.hmc_boldref_wf.val_bold
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:38,585 nipype.workflow INFO:
# 	 [Node] Finished "get_dummy", elapsed time 2.232746s.
# 240513-20:01:38,916 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.ds_hmc_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf/bold_fit_wf/ds_hmc_wf/raw_sources".
# 240513-20:01:39,526 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:39,527 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000382s.
# 240513-20:01:39,535 nipype.workflow INFO:
# 	 [Node] Finished "val_bold", elapsed time 10.252125s.
# 240513-20:01:40,34 nipype.workflow INFO:
# 	 [Job 25] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_fit_wf.hmc_boldref_wf.val_bold).
# 240513-20:01:40,36 nipype.workflow INFO:
# 	 [Job 34] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.hmc_boldref_wf.get_dummy).
# 240513-20:01:40,38 nipype.workflow INFO:
# 	 [Job 36] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.ds_hmc_wf.raw_sources).
# 240513-20:01:40,43 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 88 jobs ready. Free memory (GB): 11.99/12.00, Free processors: 3/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:40,284 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.ds_fmapreg_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf/bold_fit_wf/ds_fmapreg_wf/raw_sources".
# 240513-20:01:40,285 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_native_wf.distortion_params" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf/bold_native_wf/distortion_params".
# 240513-20:01:40,287 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_native_wf.bold_source" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf/bold_native_wf/bold_source".
# 240513-20:01:40,343 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:40,344 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000414s.
# 240513-20:01:40,347 nipype.workflow INFO:
# 	 [Node] Executing "bold_source" <nipype.interfaces.utility.base.Select>
# 240513-20:01:40,348 nipype.workflow INFO:
# 	 [Node] Finished "bold_source", elapsed time 0.000455s.
# 240513-20:01:40,757 nipype.workflow INFO:
# 	 [Node] Executing "distortion_params" <fmriprep.interfaces.resampling.DistortionParameters>
# 240513-20:01:40,759 nipype.workflow INFO:
# 	 [Node] Finished "distortion_params", elapsed time 0.00099s.
# 240513-20:01:40,813 nipype.workflow INFO:
# 	 [Job 39] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_native_wf.distortion_params).
# 240513-20:01:41,59 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.ds_bold_t1_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf/ds_bold_t1_wf/raw_sources".
# 240513-20:01:41,123 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:41,124 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000409s.
# 240513-20:01:42,34 nipype.workflow INFO:
# 	 [Job 37] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.ds_fmapreg_wf.raw_sources).
# 240513-20:01:42,35 nipype.workflow INFO:
# 	 [Job 38] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_native_wf.bold_source).
# 240513-20:01:42,36 nipype.workflow INFO:
# 	 [Job 40] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.ds_bold_t1_wf.raw_sources).
# 240513-20:01:42,40 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 85 jobs ready. Free memory (GB): 11.99/12.00, Free processors: 3/4.
#                      Currently running:
#                        * fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_fit_wf.hmc_boldref_wf.val_bold
# 240513-20:01:42,268 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_05_wf.bold_fit_wf.hmc_boldref_wf.val_bold" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_05_wf/bold_fit_wf/hmc_boldref_wf/val_bold".
# 240513-20:01:42,268 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_05_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_05_wf/bold_fit_wf/ds_hmc_boldref_wf/raw_sources".
# 240513-20:01:42,269 nipype.workflow INFO:
# 	 [Node] Setting-up "fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_05_wf.bold_fit_wf.hmc_boldref_wf.get_dummy" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_05_wf/bold_fit_wf/hmc_boldref_wf/get_dummy".
# 240513-20:01:42,347 nipype.workflow INFO:
# 	 [Node] Executing "val_bold" <niworkflows.interfaces.header.ValidateImage>
# 240513-20:01:42,351 nipype.workflow INFO:
# 	 [Node] Executing "get_dummy" <niworkflows.interfaces.bold.NonsteadyStatesDetector>
# 240513-20:01:42,352 nipype.workflow INFO:
# 	 [Node] Executing "raw_sources" <nipype.interfaces.utility.wrappers.Function>
# 240513-20:01:42,354 nipype.workflow INFO:
# 	 [Node] Finished "raw_sources", elapsed time 0.000469s.
# 240513-20:01:44,36 nipype.workflow INFO:
# 	 [Job 43] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_05_wf.bold_fit_wf.ds_hmc_boldref_wf.raw_sources).
# 240513-20:01:44,39 nipype.workflow INFO:
# ...
# 240514-02:36:43,691 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:43,713 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.020787s.
# 240514-02:36:43,796 nipype.workflow INFO:
# 	 [Job 1608] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_01_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:44,113 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:44,223 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:44,246 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.022548s.
# 240514-02:36:44,297 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:44,400 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:44,429 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.027875s.
# 240514-02:36:44,517 nipype.workflow INFO:
# 	 [Job 1609] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_02_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:44,826 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:44,928 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:44,956 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.027573s.
# 240514-02:36:45,6 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:45,105 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:45,128 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.022013s.
# 240514-02:36:45,205 nipype.workflow INFO:
# 	 [Job 1610] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_03_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:45,511 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:45,620 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:45,645 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.024371s.
# 240514-02:36:45,694 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:45,798 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:45,822 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.022978s.
# 240514-02:36:45,940 nipype.workflow INFO:
# 	 [Job 1611] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_04_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:46,257 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_05_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:46,355 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:46,377 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.021372s.
# 240514-02:36:46,426 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_05_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:46,556 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:46,583 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.026203s.
# 240514-02:36:46,672 nipype.workflow INFO:
# 	 [Job 1612] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_05_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:46,977 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_06_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:47,89 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:47,112 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.02279s.
# 240514-02:36:47,160 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_06_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:47,272 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:47,294 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.020932s.
# 240514-02:36:47,376 nipype.workflow INFO:
# 	 [Job 1613] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_06_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:47,692 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_07_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:47,801 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:47,824 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.021878s.
# 240514-02:36:47,874 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_07_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:47,969 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:47,992 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.022307s.
# 240514-02:36:48,85 nipype.workflow INFO:
# 	 [Job 1614] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_07_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:48,402 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_08_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:48,503 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:48,525 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.021506s.
# 240514-02:36:48,572 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_08_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:48,676 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:48,705 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.028118s.
# 240514-02:36:48,800 nipype.workflow INFO:
# 	 [Job 1615] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_08_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:49,112 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_09_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:49,218 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:49,245 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.025334s.
# 240514-02:36:49,295 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_09_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:49,396 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:49,421 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.02476s.
# 240514-02:36:49,513 nipype.workflow INFO:
# 	 [Job 1616] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_09_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:49,872 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_10_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:49,977 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:50,0 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.022526s.
# 240514-02:36:50,52 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_10_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:50,147 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:50,167 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.019334s.
# 240514-02:36:50,264 nipype.workflow INFO:
# 	 [Job 1617] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_10_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:50,604 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 12.00/12.00, Free processors: 4/4.
# 240514-02:36:50,839 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_11_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:50,908 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:52,435 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 1.526215s.
# 240514-02:36:52,493 nipype.workflow INFO:
# 	 [Job 2044] Completed (_ds_bold_surfs0).
# 240514-02:36:52,732 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_11_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:52,796 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:54,289 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 1.492052s.
# 240514-02:36:54,339 nipype.workflow INFO:
# 	 [Job 2045] Completed (_ds_bold_surfs1).
# 240514-02:36:54,582 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_12_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:54,655 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:56,166 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 1.509503s.
# 240514-02:36:56,216 nipype.workflow INFO:
# 	 [Job 2046] Completed (_ds_bold_surfs0).
# 240514-02:36:56,464 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_12_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:56,517 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:57,994 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 1.4767000000000001s.
# 240514-02:36:58,61 nipype.workflow INFO:
# 	 [Job 2047] Completed (_ds_bold_surfs1).
# 240514-02:36:58,296 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 12.00/12.00, Free processors: 4/4.
# 240514-02:36:58,575 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_11_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:58,680 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:58,701 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.020077s.
# 240514-02:36:58,751 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_11_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:58,855 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:58,876 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.021066s.
# 240514-02:36:58,955 nipype.workflow INFO:
# 	 [Job 1618] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_11_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:36:59,266 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs0" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_12_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs0".
# 240514-02:36:59,370 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs0" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:59,392 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs0", elapsed time 0.022222s.
# 240514-02:36:59,437 nipype.workflow INFO:
# 	 [Node] Setting-up "_ds_bold_surfs1" in "/home/jovyan/work/tmp/fmriprep/fmriprep_23_2_wf/sub_wlsubj001_wf/bold_ses_nyu3t01_task_prf_acq_PA_run_12_wf/bold_surf_wf/_target_fsnative/ds_bold_surfs/mapflow/_ds_bold_surfs1".
# 240514-02:36:59,537 nipype.workflow INFO:
# 	 [Node] Executing "_ds_bold_surfs1" <fmriprep.interfaces.DerivativesDataSink>
# 240514-02:36:59,557 nipype.workflow INFO:
# 	 [Node] Finished "_ds_bold_surfs1", elapsed time 0.018517s.
# 240514-02:36:59,638 nipype.workflow INFO:
# 	 [Job 1619] Completed (fmriprep_23_2_wf.sub_wlsubj001_wf.bold_ses_nyu3t01_task_prf_acq_PA_run_12_wf.bold_surf_wf.ds_bold_surfs).
# 240514-02:37:00,333 nipype.workflow IMPORTANT:
# 	 fMRIPrep finished successfully!
# 240514-02:37:00,341 nipype.workflow IMPORTANT:
# 	 Works derived from this fMRIPrep execution should include the boilerplate text found in <OUTPUT_PATH>/logs/CITATION.md.

# %% [markdown]
# ### Check the fMRIprep BOLD outputs

# %% [markdown]
# The `fMRIprep` command should have produced a variety of outputs, including the BOLD data projected onto the cortical surface. It also produces a variety of reports in html files that are placed in the BIDS directory. We can open these files by launching a Neurodesk Desktop instance then opening them in Firefox. To launch Neurodesktop, click on the blue plus in the upper left of the Jupyter interface, then select the "Neurodesktop" button in the first row.

# %% [markdown]
# ## Step 2. Fit PRF Models

# %% [markdown]
# ### Build the PRFModel singularity container

# %% [markdown]
# The PRFModel software is stored in a Docker container. In Neurodesk (or on a cluster) we need to start by turning this into a Singularity image.
#
# This may take some time to run, but only needs to be run once.

# %%
# %%bash
#
# # Convert the docker-image of prfanalyze-vista into a singularity image.
# singularity build \
#     tmp/prfanalyze-vista_2.2.2_3.1.1.simg \
#     docker://garikoitz/prfanalyze-vista:2.2.2_3.1.1
# Out:
# INFO:    Starting build...
# Getting image source signatures
# Copying blob sha256:f4faa6ced19cd086ef67e7b7e97e29a0a9d27bcaeb5d642047bbc89589e13b30
# Copying blob sha256:b51569e7c50720acf6860327847fe342a1afbe148d24c529fb81df105e3eed01
# Copying blob sha256:fb15d46c38dcd1ea0b1990006c3366ecd10c79d374f341687eb2cb23a2c8672e
# Copying blob sha256:58690f9b18fca6469a14da4e212c96849469f9b1be6661d2342a4bf01774aa50
# Copying blob sha256:da8ef40b9ecabc2679fe2419957220c0272a965c5cf7e0269fa1aeeb8c56f2e1
# Copying blob sha256:d46ab28b2b2efbb2df9f89997969b925585d9dab39e6124e99e6bd8c801b839a
# Copying blob sha256:78052fda4ba730b35950073437798355b832e63196ae3fc86dcaa1f01ebfdc23
# Copying blob sha256:37c9f603ecf526d7a12a14c24f278f64740353f54c959b3459e47a9763cffa90
# Copying blob sha256:b4e8fc7b2f7176ad516ee16b1b5899adfa69dd77724d3cfdcf98ddba1ae7baa4
# Copying blob sha256:b238860c41076fded809db31b775219a4ab6c197b0719faae8eb769d8583ccfd
# Copying blob sha256:e53378506c1618c1e8583bcc0ca03980aedf228a30f65dbfc9b6cf118a060a01
# Copying blob sha256:8679993beaa74a249456f0bc1bacacea07fc315b3de0f554d25a62f7e1373ead
# Copying blob sha256:9ed1a2cd53071f036fb6c573508ce7b070c01d4db510b316bd1fc6a04f18217d
# Copying blob sha256:82c532758317f385ef8ede2762d2da5ca66e88f09dc23abf4d298d57684c63ce
# Copying blob sha256:2f7080f934852f58f22158ba6c3a904d535f93de01e05bda033bbb36a6d7069f
# Copying blob sha256:917d1a07d7b5c9a24cebc2472f0a8f2c669905f5bb6da815b916b0f262b49aa1
# Copying blob sha256:2f7080f934852f58f22158ba6c3a904d535f93de01e05bda033bbb36a6d7069f
# Copying blob sha256:491ec674de0698d7c6a3ebec18dfac1051064686ec4ee6250b526abc0629d2a3
# Copying blob sha256:0bdf5a1532fbc9ecbc6f7558f6cf2ebc735c2572e64ab24490150e24e6f075a4
# Copying blob sha256:f18b49b3f6d58d2bbfbeaf589c3f86737cf71455208a96efd0c98beab6128edd
# Copying blob sha256:109d5420b56c9513f90a75165977f7563a05fed6ca5312f9e0cd0561d582c0fb
# Copying blob sha256:109d5420b56c9513f90a75165977f7563a05fed6ca5312f9e0cd0561d582c0fb
# Copying blob sha256:86233dd68d1ba6d37ca71701c4b73c05787e7e4e1b640a75beab13db8f8d1ff3
# Copying blob sha256:0eb773e2eca52e867c3763c1c784ac7fa9fc8000f0c65b35543f796775079aee
# Copying blob sha256:6d9ba896fdd7318c395065b66e5beab2cd32235c559da267c469e75e06fa4faf
# Copying blob sha256:56ec356725834365bbed0aaadd6e61638252d804cd62ba38c34e182bf30a5acd
# Copying blob sha256:99776f6825902150c6aac69c85b2b2ef8c1d04486241245d1cbb7fab0b6d9064
# Copying blob sha256:d22e8444d3ac92625a35129b74210ca77f66c9ec2ea4c56ffd06268fdca84aef
# Copying blob sha256:a111c47d0ae8601c852c71d8a266ee388cca29cf205560a23b35373a21c38668
# Copying blob sha256:f02ee71689fad9198667079be7ed5bc0978ec3532f952d55a3114484eb453d16
# Copying config sha256:743e02b211332bc6b3251837304781a37da13fec31adcf1befe593e5448974cd
# Writing manifest to image destination
# 2024/05/14 03:01:52  info unpack layer: sha256:58690f9b18fca6469a14da4e212c96849469f9b1be6661d2342a4bf01774aa50
# 2024/05/14 03:01:53  warn rootless{dev/agpgart} creating empty file in place of device 10:175
# 2024/05/14 03:01:53  warn rootless{dev/audio} creating empty file in place of device 14:4
# 2024/05/14 03:01:53  warn rootless{dev/audio1} creating empty file in place of device 14:20
# 2024/05/14 03:01:53  warn rootless{dev/audio2} creating empty file in place of device 14:36
# 2024/05/14 03:01:53  warn rootless{dev/audio3} creating empty file in place of device 14:52
# 2024/05/14 03:01:53  warn rootless{dev/audioctl} creating empty file in place of device 14:7
# 2024/05/14 03:01:53  warn rootless{dev/console} creating empty file in place of device 5:1
# 2024/05/14 03:01:53  warn rootless{dev/dsp} creating empty file in place of device 14:3
# 2024/05/14 03:01:53  warn rootless{dev/dsp1} creating empty file in place of device 14:19
# 2024/05/14 03:01:53  warn rootless{dev/dsp2} creating empty file in place of device 14:35
# 2024/05/14 03:01:53  warn rootless{dev/dsp3} creating empty file in place of device 14:51
# 2024/05/14 03:01:53  warn rootless{dev/full} creating empty file in place of device 1:7
# 2024/05/14 03:01:53  warn rootless{dev/kmem} creating empty file in place of device 1:2
# 2024/05/14 03:01:53  warn rootless{dev/loop0} creating empty file in place of device 7:0
# 2024/05/14 03:01:53  warn rootless{dev/loop1} creating empty file in place of device 7:1
# 2024/05/14 03:01:53  warn rootless{dev/loop2} creating empty file in place of device 7:2
# 2024/05/14 03:01:53  warn rootless{dev/loop3} creating empty file in place of device 7:3
# 2024/05/14 03:01:53  warn rootless{dev/loop4} creating empty file in place of device 7:4
# 2024/05/14 03:01:53  warn rootless{dev/loop5} creating empty file in place of device 7:5
# 2024/05/14 03:01:53  warn rootless{dev/loop6} creating empty file in place of device 7:6
# 2024/05/14 03:01:53  warn rootless{dev/loop7} creating empty file in place of device 7:7
# 2024/05/14 03:01:53  warn rootless{dev/mem} creating empty file in place of device 1:1
# 2024/05/14 03:01:53  warn rootless{dev/midi0} creating empty file in place of device 35:0
# 2024/05/14 03:01:53  warn rootless{dev/midi00} creating empty file in place of device 14:2
# 2024/05/14 03:01:53  warn rootless{dev/midi01} creating empty file in place of device 14:18
# 2024/05/14 03:01:53  warn rootless{dev/midi02} creating empty file in place of device 14:34
# 2024/05/14 03:01:53  warn rootless{dev/midi03} creating empty file in place of device 14:50
# 2024/05/14 03:01:53  warn rootless{dev/midi1} creating empty file in place of device 35:1
# 2024/05/14 03:01:53  warn rootless{dev/midi2} creating empty file in place of device 35:2
# 2024/05/14 03:01:53  warn rootless{dev/midi3} creating empty file in place of device 35:3
# 2024/05/14 03:01:53  warn rootless{dev/mixer} creating empty file in place of device 14:0
# 2024/05/14 03:01:53  warn rootless{dev/mixer1} creating empty file in place of device 14:16
# 2024/05/14 03:01:53  warn rootless{dev/mixer2} creating empty file in place of device 14:32
# 2024/05/14 03:01:53  warn rootless{dev/mixer3} creating empty file in place of device 14:48
# 2024/05/14 03:01:53  warn rootless{dev/mpu401data} creating empty file in place of device 31:0
# 2024/05/14 03:01:53  warn rootless{dev/mpu401stat} creating empty file in place of device 31:1
# 2024/05/14 03:01:53  warn rootless{dev/null} creating empty file in place of device 1:3
# 2024/05/14 03:01:53  warn rootless{dev/port} creating empty file in place of device 1:4
# 2024/05/14 03:01:53  warn rootless{dev/ram0} creating empty file in place of device 1:0
# 2024/05/14 03:01:53  warn rootless{dev/ram1} creating empty file in place of device 1:1
# 2024/05/14 03:01:53  warn rootless{dev/ram10} creating empty file in place of device 1:10
# 2024/05/14 03:01:53  warn rootless{dev/ram11} creating empty file in place of device 1:11
# 2024/05/14 03:01:53  warn rootless{dev/ram12} creating empty file in place of device 1:12
# 2024/05/14 03:01:53  warn rootless{dev/ram13} creating empty file in place of device 1:13
# 2024/05/14 03:01:53  warn rootless{dev/ram14} creating empty file in place of device 1:14
# 2024/05/14 03:01:53  warn rootless{dev/ram15} creating empty file in place of device 1:15
# 2024/05/14 03:01:53  warn rootless{dev/ram16} creating empty file in place of device 1:16
# 2024/05/14 03:01:53  warn rootless{dev/ram2} creating empty file in place of device 1:2
# 2024/05/14 03:01:53  warn rootless{dev/ram3} creating empty file in place of device 1:3
# 2024/05/14 03:01:53  warn rootless{dev/ram4} creating empty file in place of device 1:4
# 2024/05/14 03:01:53  warn rootless{dev/ram5} creating empty file in place of device 1:5
# 2024/05/14 03:01:53  warn rootless{dev/ram6} creating empty file in place of device 1:6
# 2024/05/14 03:01:53  warn rootless{dev/ram7} creating empty file in place of device 1:7
# 2024/05/14 03:01:53  warn rootless{dev/ram8} creating empty file in place of device 1:8
# 2024/05/14 03:01:53  warn rootless{dev/ram9} creating empty file in place of device 1:9
# 2024/05/14 03:01:53  warn rootless{dev/random} creating empty file in place of device 1:8
# 2024/05/14 03:01:53  warn rootless{dev/rmidi0} creating empty file in place of device 35:64
# 2024/05/14 03:01:53  warn rootless{dev/rmidi1} creating empty file in place of device 35:65
# 2024/05/14 03:01:53  warn rootless{dev/rmidi2} creating empty file in place of device 35:66
# 2024/05/14 03:01:53  warn rootless{dev/rmidi3} creating empty file in place of device 35:67
# 2024/05/14 03:01:53  warn rootless{dev/sequencer} creating empty file in place of device 14:1
# 2024/05/14 03:01:53  warn rootless{dev/smpte0} creating empty file in place of device 35:128
# 2024/05/14 03:01:53  warn rootless{dev/smpte1} creating empty file in place of device 35:129
# 2024/05/14 03:01:53  warn rootless{dev/smpte2} creating empty file in place of device 35:130
# 2024/05/14 03:01:53  warn rootless{dev/smpte3} creating empty file in place of device 35:131
# 2024/05/14 03:01:53  warn rootless{dev/sndstat} creating empty file in place of device 14:6
# 2024/05/14 03:01:53  warn rootless{dev/tty} creating empty file in place of device 5:0
# 2024/05/14 03:01:53  warn rootless{dev/tty0} creating empty file in place of device 4:0
# 2024/05/14 03:01:53  warn rootless{dev/tty1} creating empty file in place of device 4:1
# 2024/05/14 03:01:53  warn rootless{dev/tty2} creating empty file in place of device 4:2
# 2024/05/14 03:01:53  warn rootless{dev/tty3} creating empty file in place of device 4:3
# 2024/05/14 03:01:53  warn rootless{dev/tty4} creating empty file in place of device 4:4
# 2024/05/14 03:01:53  warn rootless{dev/tty5} creating empty file in place of device 4:5
# 2024/05/14 03:01:53  warn rootless{dev/tty6} creating empty file in place of device 4:6
# 2024/05/14 03:01:53  warn rootless{dev/tty7} creating empty file in place of device 4:7
# 2024/05/14 03:01:53  warn rootless{dev/tty8} creating empty file in place of device 4:8
# 2024/05/14 03:01:53  warn rootless{dev/tty9} creating empty file in place of device 4:9
# 2024/05/14 03:01:53  warn rootless{dev/urandom} creating empty file in place of device 1:9
# 2024/05/14 03:01:53  warn rootless{dev/zero} creating empty file in place of device 1:5
# 2024/05/14 03:01:53  info unpack layer: sha256:b51569e7c50720acf6860327847fe342a1afbe148d24c529fb81df105e3eed01
# 2024/05/14 03:01:53  info unpack layer: sha256:da8ef40b9ecabc2679fe2419957220c0272a965c5cf7e0269fa1aeeb8c56f2e1
# 2024/05/14 03:01:53  info unpack layer: sha256:fb15d46c38dcd1ea0b1990006c3366ecd10c79d374f341687eb2cb23a2c8672e
# 2024/05/14 03:01:53  info unpack layer: sha256:d46ab28b2b2efbb2df9f89997969b925585d9dab39e6124e99e6bd8c801b839a
# 2024/05/14 03:01:58  info unpack layer: sha256:f4faa6ced19cd086ef67e7b7e97e29a0a9d27bcaeb5d642047bbc89589e13b30
# 2024/05/14 03:01:58  info unpack layer: sha256:78052fda4ba730b35950073437798355b832e63196ae3fc86dcaa1f01ebfdc23
# 2024/05/14 03:01:59  info unpack layer: sha256:37c9f603ecf526d7a12a14c24f278f64740353f54c959b3459e47a9763cffa90
# 2024/05/14 03:01:59  info unpack layer: sha256:b4e8fc7b2f7176ad516ee16b1b5899adfa69dd77724d3cfdcf98ddba1ae7baa4
# 2024/05/14 03:02:04  info unpack layer: sha256:8679993beaa74a249456f0bc1bacacea07fc315b3de0f554d25a62f7e1373ead
# 2024/05/14 03:02:06  info unpack layer: sha256:9ed1a2cd53071f036fb6c573508ce7b070c01d4db510b316bd1fc6a04f18217d
# 2024/05/14 03:02:06  info unpack layer: sha256:b238860c41076fded809db31b775219a4ab6c197b0719faae8eb769d8583ccfd
# 2024/05/14 03:02:15  info unpack layer: sha256:e53378506c1618c1e8583bcc0ca03980aedf228a30f65dbfc9b6cf118a060a01
# 2024/05/14 03:02:16  info unpack layer: sha256:82c532758317f385ef8ede2762d2da5ca66e88f09dc23abf4d298d57684c63ce
# 2024/05/14 03:03:15  info unpack layer: sha256:917d1a07d7b5c9a24cebc2472f0a8f2c669905f5bb6da815b916b0f262b49aa1
# 2024/05/14 03:03:15  info unpack layer: sha256:2f7080f934852f58f22158ba6c3a904d535f93de01e05bda033bbb36a6d7069f
# 2024/05/14 03:03:15  info unpack layer: sha256:2f7080f934852f58f22158ba6c3a904d535f93de01e05bda033bbb36a6d7069f
# 2024/05/14 03:03:15  info unpack layer: sha256:491ec674de0698d7c6a3ebec18dfac1051064686ec4ee6250b526abc0629d2a3
# 2024/05/14 03:03:15  info unpack layer: sha256:0bdf5a1532fbc9ecbc6f7558f6cf2ebc735c2572e64ab24490150e24e6f075a4
# 2024/05/14 03:03:15  info unpack layer: sha256:f18b49b3f6d58d2bbfbeaf589c3f86737cf71455208a96efd0c98beab6128edd
# 2024/05/14 03:03:15  info unpack layer: sha256:109d5420b56c9513f90a75165977f7563a05fed6ca5312f9e0cd0561d582c0fb
# 2024/05/14 03:03:15  info unpack layer: sha256:109d5420b56c9513f90a75165977f7563a05fed6ca5312f9e0cd0561d582c0fb
# 2024/05/14 03:03:15  info unpack layer: sha256:86233dd68d1ba6d37ca71701c4b73c05787e7e4e1b640a75beab13db8f8d1ff3
# 2024/05/14 03:03:15  info unpack layer: sha256:0eb773e2eca52e867c3763c1c784ac7fa9fc8000f0c65b35543f796775079aee
# 2024/05/14 03:03:15  info unpack layer: sha256:6d9ba896fdd7318c395065b66e5beab2cd32235c559da267c469e75e06fa4faf
# 2024/05/14 03:03:15  info unpack layer: sha256:56ec356725834365bbed0aaadd6e61638252d804cd62ba38c34e182bf30a5acd
# 2024/05/14 03:03:15  info unpack layer: sha256:99776f6825902150c6aac69c85b2b2ef8c1d04486241245d1cbb7fab0b6d9064
# 2024/05/14 03:03:15  info unpack layer: sha256:d22e8444d3ac92625a35129b74210ca77f66c9ec2ea4c56ffd06268fdca84aef
# 2024/05/14 03:03:15  info unpack layer: sha256:a111c47d0ae8601c852c71d8a266ee388cca29cf205560a23b35373a21c38668
# 2024/05/14 03:03:15  info unpack layer: sha256:f02ee71689fad9198667079be7ed5bc0978ec3532f952d55a3114484eb453d16
# INFO:    Creating SIF file...
# INFO:    Build complete: tmp/prfanalyze-vista_2.2.2_3.1.1.simg

# %% [markdown]
# ### Make a PRFModel configuration file

# %% [markdown]
# In order to run the PRFModel container, we need to provide it with a configuration JSON file. This
# primarily contains information about the data that is to be fit and how to perform that fit. More
# information can be found on the [PRFModel wiki](https://github.com/vistalab/PRFmodel/wiki). Because
# PRFModel expects this to be called `config.json`, we write it out with this name (though we can
# change it late).

# %%
# %%writefile config.json
# {
#     "subjectName": "wlsubj001",
#     "sessionName": "nyu3t01",
#     "tasks": "prf",
#     "isPRFSynthData": false,
#     "solver": "vista",
#     "options": {
#         "prfprepareAnalysis": "01"
#     },
#     "stimulus": {
#         "stimulus_diameter": 24
#     }
# }
# Out:
# Writing config.json

# %% [markdown]
# ### Organize the BOLD data for PRFModel

# %% [markdown]
# #### The Stimulus Files

# %% [markdown]
# We also need to make sure that the stimulus information is available to PRFModel. PRFModel expects the
# stimulus apertures to be stored in the `stimuli` subdirectory of the BIDS directory.

# %%
# %%bash
#
# FILENAME=sub-wlsubj001_ses-nyu3t01_task-prf_apertures.nii.gz
# DIR=BIDS/derivatives/prfprepare/analysis-01/sub-wlsubj001/stimuli/
#
# mkdir -p "$DIR"
# cp "$STIMULUS_FILE" "$DIR/$FILENAME"

# %% [markdown]
# #### The BOLD files

# %%
# %%bash
#
# BASEDIR=BIDS/derivatives/prfprepare
#
# mkdir -p $BASEDIR/analysis-01/sub-wlsubj001/ses-nyu3t01/func

# %%
import nibabel as nib
import numpy as np

subject = 'wlsubj001'
session = 'nyu3t01'
task = 'prf'

# Where we find the data and what it's called (and what we will rename it).
subdir_part = f'sub-{subject}/ses-{session}/func'
func_dir = f'BIDS/{subdir_part}'
prep_dir = f'BIDS/derivatives/prfprepare/analysis-01/{subdir_part}'
file_head = f'sub-{subject}_ses-{session}_task-{task}'

# We're going to convert the files for both hemispheres
for hemi in ['L', 'R']:
    # All the GIFTI files of a single hemisphere end like this:
    file_tail = f'hemi-{hemi}_space-fsnative_bold.func.gii'
    # We'll convert the files for these runs:
    for run in ['01']:
        gii_filename = f'{func_dir}/{file_head}_acq-PA_run-{run}_{file_tail}'
        nii_filename = f'{prep_dir}/{file_head}_run-{run}_hemi-{hemi}_bold.nii.gz'
        # Load in the GIFTI file.
        gii = nib.load(gii_filename)
        # Convert it into a NIFTI image.
        signals = np.transpose([row.data for row in gii.darrays])
        signals = signals[:,None,None,...]
        nii = nib.Nifti2Image(signals, np.eye(4))
        nii.header.set_xyzt_units('mm', 'sec')
        # Save it out to the directory.
        nib.save(nii, nii_filename)

# %% [markdown]
# We also need to make events files for the `prfprepare` directory. These files usually document when during experiments particular stimuli appear, but PRFModel just needs to know the stimulus file, so we can make these quite simple.

# %%
# %%writefile BIDS/derivatives/prfprepare/analysis-01/sub-wlsubj001/ses-nyu3t01/func/sub-wlsubj001_ses-nyu3t01_task-prf_events.tsv
# stim_file
# sub-wlsubj001_ses-nyu3t01_task-prf_apertures.nii.gz
# Out:
# Writing BIDS/derivatives/prfprepare/analysis-01/sub-wlsubj001/ses-nyu3t01/func/sub-wlsubj001_ses-nyu3t01_task-prf_events.tsv

# %% [markdown]
# ### Run the PRFModel Singularity Container

# %%
# %%bash
#
# # Clear the default singularity bind-paths.
# export SINGULARITY_BINDPATH=""
# export APPTAINER_BINDPATH=""
#
# # Run the container with the bind-paths that prfmodel expects.
# singularity run \
#     --bind $PWD:/flywheel/v0/input \
#     --bind $PWD:/flywheel/v0/output \
#     tmp/prfanalyze-vista_2.2.2_3.1.1.simg
# Out:
# ------------------------------------------
# Setting up environment variables
# ---
# LD_LIBRARY_PATH is .:/opt/mcr/v99//runtime/glnxa64:/opt/mcr/v99//bin/glnxa64:/opt/mcr/v99//sys/os/glnxa64:/opt/mcr/v99//sys/opengl/lib/glnxa64
# This is the config.json file being read: /flywheel/v0/output/BIDS/derivatives/prfanalyze-vista/analysis-02/options.json
# These are the contents of the json file:
#
# tmp =
#
#   struct with fields:
#
#     prfprepareAnalysis: '01'
#
# ================================================================================
# /flywheel/v0/input/BIDS/derivatives/prfprepare/analysis-01/sub-wlsubj001/ses-nyu3t01/func/sub-wlsubj001_ses-nyu3t01_task-prf_run-01_hemi-L_bold.nii.gz
# /tmp/tmpx9jo7u5r.json
# /flywheel/v0/input/BIDS/derivatives/prfprepare/analysis-01/sub-wlsubj001/stimuli/sub-wlsubj001_ses-nyu3t01_task-prf_apertures.nii.gz
# /flywheel/v0/output/BIDS/derivatives/prfanalyze-vista/analysis-02/options.json
# --------------------------------------------------------------------------------
# This is the options file comming in:
#
# allOptions =
#
#   struct with fields:
#
#     vista: [1x1 struct]
#      aprf: [1x1 struct]
#      afni: [1x1 struct]
#       mlr: [1x1 struct]
#
#
# ans =
#
#   struct with fields:
#
#           prfprepareAnalysis: '01'
#                        model: 'one gaussian'
#                         grid: 0
#                      wSearch: 'coarse to fine'
#                      detrend: 1
#                keepAllPoints: 0
#                  obtainPreds: 0
#                    fixcssexp: 0
#                          hrf: []
#     numberStimulusGridPoints: 50
#
#
# timePointsN =
#
#    192
#
#
# niftiBOLDfile =
#
#     '/home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/tmp.nii.gz'
#
# Warning: mrvista is assuming all stimuli with same radius. Fix this
# > In pmModelFit (line 482)
# In prfanalyze_vista (line 92)
#
# [pmVistasoft] This is homedir: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d
#
# [pmVistasoft] This is stimfile: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/tmpstim.nii.gz
#
# [pmVistasoft] This is datafile: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/tmp.nii.gz
#
# [pmVistasoft] This is stimradius: 12
#
# [pmVistasoft] This is the hrf:
# hrf =
#
#      []
#
#
# ans =
#
#     '
#
#       USING TR:1.00
#
#      '
#
# ***** [mrInit] Initializing Session pRFsynthetic01 ***** (14-May-2024 16:36:18)
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [97542.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/tmp.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/tmp.nii.gz
# [mrInit]: Finished initializing mrVista session. 	(14-May-2024 16:36:21)
# Initializing HIDDEN Inplane view
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [97542.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/inplane.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/inplane.nii.gz
# ***** [mrInit] Finished Initializing Session pRFsynthetic01 (14-May-2024 16:36:21)*****
#
# params =
#
#   struct with fields:
#
#                   inplane: './Raw/inplane.nii.gz'
#               functionals: './Raw/tmp.nii.gz'
#                  vAnatomy: []
#                sessionDir: '/home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d'
#               sessionCode: 'pRFsynthetic01'
#                   subject: ''
#               description: ''
#                  comments: ''
#                keepFrames: []
#               annotations: {}
#                   parfile: {}
#                  coParams: {}
#                 glmParams: {}
#                scanGroups: {}
#                  applyGlm: 0
#              applyCorAnal: []
#                motionComp: 0
#     sliceTimingCorrection: 0
#         motionCompRefScan: 1
#        motionCompRefFrame: 1
#                 alignment: []
#
#
# .               ..              inplane.nii.gz  tmp.nii.gz
#
# Initializing HIDDEN Inplane view
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [97542.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/inplane.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/inplane.nii.gz
#                      name: 'Original'
#                scanParams: [1x1 struct]
#     blockedAnalysisParams: [1x1 struct]
#       eventAnalysisParams: [1x1 struct]
#
#
# ans =
#
#   struct with fields:
#
#      annotation: []
#         nFrames: 192
#     framePeriod: 1
#          slices: 1
#        cropSize: [1 195085]
#       PfileName: './Raw/tmp.nii.gz'
#     inplanePath: './Raw/tmp.nii.gz'
#      keepFrames: [0 -1]
#         parfile: ''
#       scanGroup: 'Original: 1'
#
#
# sParams =
#
#   struct with fields:
#
#            stimType: '8Bars'
#            stimSize: 14
#           stimWidth: 45
#           stimStart: 0
#             stimDir: 0
#             nCycles: 6
#          nStimOnOff: 0
#          nUniqueRep: 1
#     prescanDuration: 8
#                nDCT: 0
#             hrfType: 'one gamma (Boynton style)'
#           hrfParams: {[1.6800 3 2.0500]  [5.4000 5.2000 10.8000 7.3500 0.3500]}
#           hrfCustom: []
#         framePeriod: 1
#             nFrames: 192
#          fliprotate: [0 0 0]
#              imFile: 'None'
#          jitterFile: 'None'
#          paramsFile: 'None'
#            imFilter: 'None'
#
# [rmDefineParameters]:Stimulus size: 12.00deg.
# [rmDefineParameters]:Scan 1:HRF type: [two gammas (spm style)]; parameters: [ 5.40 5.20 10.80 7.35 0.35]. (14-May-2024 16:36:21)
# [rmDefineParameters]:Not a Gray view (Inplane): ABANDONING coarse-to-fine approach (that means no initial smoothing of the data).
# [rmDefineParameters]:PRF size spacing: from 0.20 to 12.00 deg (24).
# [rmDefineParameters]:Stimulus sample size: 0.24 deg.
# [rmDefineParameters]:Minimimal pRF position spacing in triangular grid: 0.48 deg.
# [rmDefineParameters]:Number of [x,y,s] models for grid search: 126270.
# [makeStimFromScan]: Loading images: ./Stimuli/images_and_params...
# [makeStimFromScan]: Loading images for scan 1...
# [makeStimFromScan]: Filtering images...
# Warning: [makeStimFromScan]: No calibration file found. This may affect image filtering.
# > In makeStimFromScan>subFilterImages (line 175)
# In makeStimFromScan (line 105)
# In rmMakeStimulus (line 83)
# In rmLoadParameters (line 20)
# In pmVistasoft (line 198)
# In pmModelFit (line 499)
# In prfanalyze_vista (line 92)
# No filtering
# [makeStimFromScan]: Downsampling images to stimulus grid...
# [makeStimFromScan]: Averaging images within a TR...
# [makeStimFromScan]: Done.
# Initializing HIDDEN Inplane view
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [97542.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/inplane.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/inplane.nii.gz
# [reserveToolbox]:optimization toolbox reserved.
# [rmDefineParameters]:Resetting parameter: model, fixcssexp, matFileName, keepAllPoints, numberStimulusGridPoints,.
# [rmDefineParameters]:Stimulus size: 12.00deg.
# [rmDefineParameters]:Scan 1:HRF type: [two gammas (spm style)]; parameters: [ 5.40 5.20 10.80 7.35 0.35]. (14-May-2024 16:36:22)
# [rmDefineParameters]:Resetting parameter: model, fixcssexp, matFileName, keepAllPoints, numberStimulusGridPoints,.
# [rmDefineParameters]:Not a Gray view (Inplane): ABANDONING coarse-to-fine approach (that means no initial smoothing of the data).
# [rmDefineParameters]:PRF size spacing: from 0.20 to 12.00 deg (24).
# [rmDefineParameters]:Stimulus sample size: 0.24 deg.
# [rmDefineParameters]:Minimimal pRF position spacing in triangular grid: 0.48 deg.
# [rmDefineParameters]:Number of [x,y,s] models for grid search: 126270.
# [rmDefineParameters]:Resetting parameter: model, fixcssexp, matFileName, keepAllPoints, numberStimulusGridPoints,.
# [rmDefineParameters]:Resetting parameter: model, fixcssexp, matFileName, keepAllPoints, numberStimulusGridPoints,.
# [makeStimFromScan]: Loading images: ./Stimuli/images_and_params...
# [makeStimFromScan]: Loading images for scan 1...
# [makeStimFromScan]: Filtering images...
# Warning: [makeStimFromScan]: No calibration file found. This may affect image filtering.
# > In makeStimFromScan>subFilterImages (line 175)
# In makeStimFromScan (line 105)
# In rmMakeStimulus (line 83)
# In rmMain (line 100)
# In pmVistasoft (line 207)
# In pmModelFit (line 499)
# In prfanalyze_vista (line 92)
# No filtering
# [makeStimFromScan]: Downsampling images to stimulus grid...
# [makeStimFromScan]: Averaging images within a TR...
# [makeStimFromScan]: Done.
# [rmMain]:Two stage coarse-to-fine fit.
# [rmGridFit]:Making 126270 model samples:..........Done[0 min].	(14-May-2024 16:36:31)
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [97542.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/tmp.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/tmp.nii.gz
# [rmMakeTrends]: Removing 3 trends from combined data.
# [rmGridFit]: Decimating data:...
# [rmGridFit]:Number of voxels: 195085.
# [rmGridFit_oneGaussian]:Estimated processing time: 2 hours.	(14-May-2024 16:46:45)
# [rmGridFit_oneGaussian]:Grid (x,y,sigma) fit:..........Done[2 hours].	(14-May-2024 18:11:39)
# [rmSave]:Saved /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Inplane/Original/tmpResults-gFit.mat.
# [reserveToolbox]:optimization toolbox reserved.
# [rmMakeTrends]: Removing 3 trends from combined data.
# [rmSearchFit]:Processing voxels with variance explained >= 0.10
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [97542.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/tmp.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/tmp.nii.gz
# [rmSearchFit_oneGaussian]:Estimated processing time: 68137 voxels: 2 hours.
# [rmSearchFit_oneGaussian]:Nonlinear optimization (x,y,sigma):........Warning: Matrix is close to singular or badly scaled. Results may be inaccurate. RCOND =  8.712089e-17.
# > In backsolveSys
# In solveKKTsystem
# In computeTrialStep
# In barrier
# In fmincon (line 848)
# In rmSearchFit_oneGaussian (line 66)
# In rmSearchFit (line 362)
# In rmMain (line 128)
# In pmVistasoft (line 207)
# In pmModelFit (line 499)
# In prfanalyze_vista (line 92)
#
# ..Done [2 hours].
# [rmSearchFit_oneGaussian]:Removed negative fits: 0 (0.0%).
# [rmSave]:Saved /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Inplane/Original/tmpResults-sFit.mat.
# [reserveToolbox]:optimization toolbox reserved.
# [rmMakeTrends]: Removing 3 trends from combined data.
# [rmSearchFit]:Processing voxels with variance explained >= 0.00
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [97542.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/tmp.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Raw/tmp.nii.gz
# [rmSearchFit_oneGaussian]:Estimated processing time: 195085 voxels: 2 minutes.
# [rmSearchFit_oneGaussian]:Nonlinear optimization (x,y,sigma):..........Done [2 minutes].
# [rmSearchFit_oneGaussian]:Removed negative fits: 0 (0.0%).
# [rmSave]:Saved /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb540dc43_658b_47f7_9940_bad7bdabe29d/Inplane/Original/tmpResults-fFit.mat.
# Warning: Calling STRUCT on an object prevents the object from hiding its implementation details and should thus be avoided. Use DISP or DISPLAY to see the visible public details of an object. See 'help struct' for more information.
# > In prfanalyze_vista (line 95)
# Elapsed time is 249.129510 seconds.
# real	189m19.456s
# user	371m42.841s
# sys	216m46.598s
# ------------------------------------------
# Setting up environment variables
# ---
# LD_LIBRARY_PATH is .:/opt/mcr/v99//runtime/glnxa64:/opt/mcr/v99//bin/glnxa64:/opt/mcr/v99//sys/os/glnxa64:/opt/mcr/v99//sys/opengl/lib/glnxa64
# This is the config.json file being read: /flywheel/v0/output/BIDS/derivatives/prfanalyze-vista/analysis-02/options.json
# These are the contents of the json file:
#
# tmp =
#
#   struct with fields:
#
#     prfprepareAnalysis: '01'
#
# ================================================================================
# /flywheel/v0/input/BIDS/derivatives/prfprepare/analysis-01/sub-wlsubj001/ses-nyu3t01/func/sub-wlsubj001_ses-nyu3t01_task-prf_run-01_hemi-R_bold.nii.gz
# /tmp/tmpf9ojzio7.json
# /flywheel/v0/input/BIDS/derivatives/prfprepare/analysis-01/sub-wlsubj001/stimuli/sub-wlsubj001_ses-nyu3t01_task-prf_apertures.nii.gz
# /flywheel/v0/output/BIDS/derivatives/prfanalyze-vista/analysis-02/options.json
# --------------------------------------------------------------------------------
# This is the options file comming in:
#
# allOptions =
#
#   struct with fields:
#
#     vista: [1x1 struct]
#      aprf: [1x1 struct]
#      afni: [1x1 struct]
#       mlr: [1x1 struct]
#
#
# ans =
#
#   struct with fields:
#
#           prfprepareAnalysis: '01'
#                        model: 'one gaussian'
#                         grid: 0
#                      wSearch: 'coarse to fine'
#                      detrend: 1
#                keepAllPoints: 0
#                  obtainPreds: 0
#                    fixcssexp: 0
#                          hrf: []
#     numberStimulusGridPoints: 50
#
#
# timePointsN =
#
#    192
#
#
# niftiBOLDfile =
#
#     '/home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/tmp.nii.gz'
#
# Warning: mrvista is assuming all stimuli with same radius. Fix this
# > In pmModelFit (line 482)
# In prfanalyze_vista (line 92)
#
# [pmVistasoft] This is homedir: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3
#
# [pmVistasoft] This is stimfile: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/tmpstim.nii.gz
#
# [pmVistasoft] This is datafile: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/tmp.nii.gz
#
# [pmVistasoft] This is stimradius: 12
#
# [pmVistasoft] This is the hrf:
# hrf =
#
#      []
#
#
# ans =
#
#     '
#
#       USING TR:1.00
#
#      '
#
# ***** [mrInit] Initializing Session pRFsynthetic01 ***** (14-May-2024 19:46:05)
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [96152.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/tmp.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/tmp.nii.gz
# [mrInit]: Finished initializing mrVista session. 	(14-May-2024 19:46:07)
# Initializing HIDDEN Inplane view
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [96152.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/inplane.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/inplane.nii.gz
# ***** [mrInit] Finished Initializing Session pRFsynthetic01 (14-May-2024 19:46:08)*****
#
# params =
#
#   struct with fields:
#
#                   inplane: './Raw/inplane.nii.gz'
#               functionals: './Raw/tmp.nii.gz'
#                  vAnatomy: []
#                sessionDir: '/home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3'
#               sessionCode: 'pRFsynthetic01'
#                   subject: ''
#               description: ''
#                  comments: ''
#                keepFrames: []
#               annotations: {}
#                   parfile: {}
#                  coParams: {}
#                 glmParams: {}
#                scanGroups: {}
#                  applyGlm: 0
#              applyCorAnal: []
#                motionComp: 0
#     sliceTimingCorrection: 0
#         motionCompRefScan: 1
#        motionCompRefFrame: 1
#                 alignment: []
#
#
# .               ..              inplane.nii.gz  tmp.nii.gz
#
# Initializing HIDDEN Inplane view
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [96152.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/inplane.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/inplane.nii.gz
#                      name: 'Original'
#                scanParams: [1x1 struct]
#     blockedAnalysisParams: [1x1 struct]
#       eventAnalysisParams: [1x1 struct]
#
#
# ans =
#
#   struct with fields:
#
#      annotation: []
#         nFrames: 192
#     framePeriod: 1
#          slices: 1
#        cropSize: [1 192305]
#       PfileName: './Raw/tmp.nii.gz'
#     inplanePath: './Raw/tmp.nii.gz'
#      keepFrames: [0 -1]
#         parfile: ''
#       scanGroup: 'Original: 1'
#
#
# sParams =
#
#   struct with fields:
#
#            stimType: '8Bars'
#            stimSize: 14
#           stimWidth: 45
#           stimStart: 0
#             stimDir: 0
#             nCycles: 6
#          nStimOnOff: 0
#          nUniqueRep: 1
#     prescanDuration: 8
#                nDCT: 0
#             hrfType: 'one gamma (Boynton style)'
#           hrfParams: {[1.6800 3 2.0500]  [5.4000 5.2000 10.8000 7.3500 0.3500]}
#           hrfCustom: []
#         framePeriod: 1
#             nFrames: 192
#          fliprotate: [0 0 0]
#              imFile: 'None'
#          jitterFile: 'None'
#          paramsFile: 'None'
#            imFilter: 'None'
#
# [rmDefineParameters]:Stimulus size: 12.00deg.
# [rmDefineParameters]:Scan 1:HRF type: [two gammas (spm style)]; parameters: [ 5.40 5.20 10.80 7.35 0.35]. (14-May-2024 19:46:08)
# [rmDefineParameters]:Not a Gray view (Inplane): ABANDONING coarse-to-fine approach (that means no initial smoothing of the data).
# [rmDefineParameters]:PRF size spacing: from 0.20 to 12.00 deg (24).
# [rmDefineParameters]:Stimulus sample size: 0.24 deg.
# [rmDefineParameters]:Minimimal pRF position spacing in triangular grid: 0.48 deg.
# [rmDefineParameters]:Number of [x,y,s] models for grid search: 126270.
# [makeStimFromScan]: Loading images: ./Stimuli/images_and_params...
# [makeStimFromScan]: Loading images for scan 1...
# [makeStimFromScan]: Filtering images...
# Warning: [makeStimFromScan]: No calibration file found. This may affect image filtering.
# > In makeStimFromScan>subFilterImages (line 175)
# In makeStimFromScan (line 105)
# In rmMakeStimulus (line 83)
# In rmLoadParameters (line 20)
# In pmVistasoft (line 198)
# In pmModelFit (line 499)
# In prfanalyze_vista (line 92)
# No filtering
# [makeStimFromScan]: Downsampling images to stimulus grid...
# [makeStimFromScan]: Averaging images within a TR...
# [makeStimFromScan]: Done.
# Initializing HIDDEN Inplane view
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [96152.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/inplane.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/inplane.nii.gz
# [reserveToolbox]:optimization toolbox reserved.
# [rmDefineParameters]:Resetting parameter: model, fixcssexp, matFileName, keepAllPoints, numberStimulusGridPoints,.
# [rmDefineParameters]:Stimulus size: 12.00deg.
# [rmDefineParameters]:Scan 1:HRF type: [two gammas (spm style)]; parameters: [ 5.40 5.20 10.80 7.35 0.35]. (14-May-2024 19:46:09)
# [rmDefineParameters]:Resetting parameter: model, fixcssexp, matFileName, keepAllPoints, numberStimulusGridPoints,.
# [rmDefineParameters]:Not a Gray view (Inplane): ABANDONING coarse-to-fine approach (that means no initial smoothing of the data).
# [rmDefineParameters]:PRF size spacing: from 0.20 to 12.00 deg (24).
# [rmDefineParameters]:Stimulus sample size: 0.24 deg.
# [rmDefineParameters]:Minimimal pRF position spacing in triangular grid: 0.48 deg.
# [rmDefineParameters]:Number of [x,y,s] models for grid search: 126270.
# [rmDefineParameters]:Resetting parameter: model, fixcssexp, matFileName, keepAllPoints, numberStimulusGridPoints,.
# [rmDefineParameters]:Resetting parameter: model, fixcssexp, matFileName, keepAllPoints, numberStimulusGridPoints,.
# [makeStimFromScan]: Loading images: ./Stimuli/images_and_params...
# [makeStimFromScan]: Loading images for scan 1...
# [makeStimFromScan]: Filtering images...
# Warning: [makeStimFromScan]: No calibration file found. This may affect image filtering.
# > In makeStimFromScan>subFilterImages (line 175)
# In makeStimFromScan (line 105)
# In rmMakeStimulus (line 83)
# In rmMain (line 100)
# In pmVistasoft (line 207)
# In pmModelFit (line 499)
# In prfanalyze_vista (line 92)
# No filtering
# [makeStimFromScan]: Downsampling images to stimulus grid...
# [makeStimFromScan]: Averaging images within a TR...
# [makeStimFromScan]: Done.
# [rmMain]:Two stage coarse-to-fine fit.
# [rmGridFit]:Making 126270 model samples:..........Done[0 min].	(14-May-2024 19:46:18)
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [96152.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/tmp.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/tmp.nii.gz
# [rmMakeTrends]: Removing 3 trends from combined data.
# [rmGridFit]: Decimating data:...
# [rmGridFit]:Number of voxels: 192305.
# [rmGridFit_oneGaussian]:Estimated processing time: 2 hours.	(14-May-2024 19:55:54)
# [rmGridFit_oneGaussian]:Grid (x,y,sigma) fit:..........Done[2 hours].	(14-May-2024 21:13:33)
# [rmSave]:Saved /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Inplane/Original/tmpResults-gFit.mat.
# [reserveToolbox]:optimization toolbox reserved.
# [rmMakeTrends]: Removing 3 trends from combined data.
# [rmSearchFit]:Processing voxels with variance explained >= 0.10
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [96152.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/tmp.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/tmp.nii.gz
# [rmSearchFit_oneGaussian]:Estimated processing time: 72042 voxels: 2 hours.
# [rmSearchFit_oneGaussian]:Nonlinear optimization (x,y,sigma):..........Done [2 hours].
# [rmSearchFit_oneGaussian]:Removed negative fits: 0 (0.0%).
# [rmSave]:Saved /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Inplane/Original/tmpResults-sFit.mat.
# [reserveToolbox]:optimization toolbox reserved.
# [rmMakeTrends]: Removing 3 trends from combined data.
# [rmSearchFit]:Processing voxels with variance explained >= 0.00
# [niftiCheckQto] ni.qform_code is zero and sform_code ~=0. Setting ni.qto_* from ni.sto_*...
# [niftiCheckQto] NIFTI header origin is at or outside the image volume.
# [niftiCheckQto] Origin to the image center [96152.500,0.500,0.500] pix.
# No freqdim field set in the nifti. Assuming freqdim = 1. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/tmp.nii.gz
# No phasedim field set in the nifti. Assuming phasedim = 2. Nifti stored at: /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Raw/tmp.nii.gz
# [rmSearchFit_oneGaussian]:Estimated processing time: 192296 voxels: 2 minutes.
# [rmSearchFit_oneGaussian]:Nonlinear optimization (x,y,sigma):..........Done [2 minutes].
# [rmSearchFit_oneGaussian]:Removed negative fits: 0 (0.0%).
# [rmSave]:Saved /home/jovyan/.mcrCache9.9/prfana0/bcbl/home/home_g-m/glerma/toolboxes/PRFmodel/local/tpb6f270c7_3262_4dfd_8caa_89828112d1e3/Inplane/Original/tmpResults-fFit.mat.
# Warning: Calling STRUCT on an object prevents the object from hiding its implementation details and should thus be avoided. Use DISP or DISPLAY to see the visible public details of an object. See 'help struct' for more information.
# > In prfanalyze_vista (line 95)
# Elapsed time is 256.991227 seconds.
# real	172m29.247s
# user	353m19.768s
# sys	260m37.584s
# Preparing solver "prfanalyze-vista":
# [base/run.py] Using real data, not coming from prfsynthesize.
#   Subject: wlsubj001
#   Session: nyu3t01
#   Options: {'prfprepareAnalysis': '01'}
# These are the tasks: ['prf']
# Output BIDS directory: /flywheel/v0/output/BIDS/derivatives/prfanalyze-vista/analysis-02/sub-wlsubj001/ses-nyu3t01
# task used in the glob command is prf
# ['/flywheel/v0/input/BIDS/derivatives/prfprepare/analysis-01/sub-wlsubj001/ses-nyu3t01/func/sub-wlsubj001_ses-nyu3t01_task-prf_run-01_hemi-R_bold.nii.gz', '/flywheel/v0/input/BIDS/derivatives/prfprepare/analysis-01/sub-wlsubj001/ses-nyu3t01/func/sub-wlsubj001_ses-nyu3t01_task-prf_run-01_hemi-L_bold.nii.gz']
# 2
# [base/run.py] This is the temp file with stim info:
# /tmp/tmpx9jo7u5r.json
# [base/run.py] This is the content:
# {'stimulus_diameter': 24, 'isPRFSynthData': False}
# Beginning os.wait() for /solve.sh, run=01 (child pid is 65814)
# Processing estimates.json file...
# Writing the estimates.json to nifti2 in outbids_dir: /flywheel/v0/output/BIDS/derivatives/prfanalyze-vista/analysis-02/sub-wlsubj001/ses-nyu3t01
# [base/run.py] This is the temp file with stim info:
# /tmp/tmpf9ojzio7.json
# [base/run.py] This is the content:
# {'stimulus_diameter': 24, 'isPRFSynthData': False}
# Beginning os.wait() for /solve.sh, run=01 (child pid is 91770)
# Processing estimates.json file...
# Writing the estimates.json to nifti2 in outbids_dir: /flywheel/v0/output/BIDS/derivatives/prfanalyze-vista/analysis-02/sub-wlsubj001/ses-nyu3t01

# %% [markdown]
# ## Step 3. Visualize and Annotate the Retinotopic Maps

# %% [markdown]
# The final step in our preprocessing is to visualize the maps and delineate the boundaries of the visual areas in the occipital cortex. There are many tools for doing this including AFNI and VistaSoft, but all have substantial limitations. We will use a tool called [`cortex-annotate`](https://github.com/noahbenson/cortex-annotate), which was designed with the goals of being highly flexible and of allowing many raters to individually draw then merge annotations of a dataset using GitHub.
#
# Typically one has to configure `cortex-annotate` to work with a dataset (substantial documentation about this can be found on the `cortex-annotate` GitHub pate), but because we are using the output of `PRFModel`, we can use a preconfigured interface.
#
# First, we install the package.

# %%
# %%bash
#
# pip install 'cortexannotate == 0.1.4'
# Out:
# Collecting cortexannotate==0.1.4
#   Downloading cortexannotate-0.1.4-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: neuropythy>=0.12.13 in /opt/conda/lib/python3.11/site-packages (from cortexannotate==0.1.4) (0.12.13)
# Requirement already satisfied: pandas>=2.2.2 in /opt/conda/lib/python3.11/site-packages (from cortexannotate==0.1.4) (2.2.2)
# Requirement already satisfied: pyyaml>=6.0.1 in /opt/conda/lib/python3.11/site-packages (from cortexannotate==0.1.4) (6.0.1)
# Requirement already satisfied: ipywidgets>=8.1.2 in /opt/conda/lib/python3.11/site-packages (from cortexannotate==0.1.4) (8.1.2)
# Requirement already satisfied: ipycanvas>=0.13.2 in /opt/conda/lib/python3.11/site-packages (from cortexannotate==0.1.4) (0.13.2)
# Requirement already satisfied: imageio>=2.26.0 in /opt/conda/lib/python3.11/site-packages (from cortexannotate==0.1.4) (2.34.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from imageio>=2.26.0->cortexannotate==0.1.4) (1.26.4)
# Requirement already satisfied: pillow>=8.3.2 in /opt/conda/lib/python3.11/site-packages (from imageio>=2.26.0->cortexannotate==0.1.4) (10.3.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/conda/lib/python3.11/site-packages (from ipywidgets>=8.1.2->cortexannotate==0.1.4) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /opt/conda/lib/python3.11/site-packages (from ipywidgets>=8.1.2->cortexannotate==0.1.4) (8.16.1)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.11/site-packages (from ipywidgets>=8.1.2->cortexannotate==0.1.4) (5.11.2)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /opt/conda/lib/python3.11/site-packages (from ipywidgets>=8.1.2->cortexannotate==0.1.4) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /opt/conda/lib/python3.11/site-packages (from ipywidgets>=8.1.2->cortexannotate==0.1.4) (3.0.10)
# Requirement already satisfied: scipy>=1.1 in /opt/conda/lib/python3.11/site-packages (from neuropythy>=0.12.13->cortexannotate==0.1.4) (1.13.0)
# Requirement already satisfied: six>=1.13 in /opt/conda/lib/python3.11/site-packages (from neuropythy>=0.12.13->cortexannotate==0.1.4) (1.16.0)
# Requirement already satisfied: nibabel>=2.0 in /opt/conda/lib/python3.11/site-packages (from neuropythy>=0.12.13->cortexannotate==0.1.4) (5.2.1)
# Requirement already satisfied: pyrsistent>=0.11 in /opt/conda/lib/python3.11/site-packages (from neuropythy>=0.12.13->cortexannotate==0.1.4) (0.20.0)
# Requirement already satisfied: pint>=0.7 in /opt/conda/lib/python3.11/site-packages (from neuropythy>=0.12.13->cortexannotate==0.1.4) (0.23)
# Requirement already satisfied: pimms>=0.3.22 in /opt/conda/lib/python3.11/site-packages (from neuropythy>=0.12.13->cortexannotate==0.1.4) (0.3.23)
# Requirement already satisfied: py4j>=0.10 in /opt/conda/lib/python3.11/site-packages (from neuropythy>=0.12.13->cortexannotate==0.1.4) (0.10.9.7)
# Requirement already satisfied: h5py>=2.8.0 in /opt/conda/lib/python3.11/site-packages (from neuropythy>=0.12.13->cortexannotate==0.1.4) (3.11.0)
# Requirement already satisfied: s3fs>=0.1.5 in /opt/conda/lib/python3.11/site-packages (from neuropythy>=0.12.13->cortexannotate==0.1.4) (2024.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2.2->cortexannotate==0.1.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2.2->cortexannotate==0.1.4) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas>=2.2.2->cortexannotate==0.1.4) (2024.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (4.8.0)
# Requirement already satisfied: packaging>=17 in /opt/conda/lib/python3.11/site-packages (from nibabel>=2.0->neuropythy>=0.12.13->cortexannotate==0.1.4) (23.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from pint>=0.7->neuropythy>=0.12.13->cortexannotate==0.1.4) (4.8.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /opt/conda/lib/python3.11/site-packages (from s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (2.13.0)
# Requirement already satisfied: fsspec==2024.5.0.* in /opt/conda/lib/python3.11/site-packages (from s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (2024.5.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.11/site-packages (from s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (3.9.4)
# Requirement already satisfied: botocore<1.34.107,>=1.34.70 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (1.34.106)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (0.11.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (1.9.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (2.4.0)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8.1.2->cortexannotate==0.1.4) (0.2.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from botocore<1.34.107,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (1.0.1)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.11/site-packages (from botocore<1.34.107,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (2.0.7)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.11/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs>=0.1.5->neuropythy>=0.12.13->cortexannotate==0.1.4) (3.4)
# Downloading cortexannotate-0.1.4-py3-none-any.whl (36 kB)
# Installing collected packages: cortexannotate
#   Attempting uninstall: cortexannotate
#     Found existing installation: cortexannotate 0.1.3
#     Uninstalling cortexannotate-0.1.3:
#       Successfully uninstalled cortexannotate-0.1.3
# Successfully installed cortexannotate-0.1.4

# %% [markdown]
# Finally, we can run the `cortex-annotate` and annotate the maps!

# %%
from cortexannotate import annotate_prfs

tool = annotate_prfs(
    'BIDS',
    prf_format='prfanalyze-vista',
    derivative='cortexannotate',
    overwrite=True,
    invert_y=True)
